# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from matplotlib.widgets import Cursor
from scipy.optimize import curve_fit
from scipy.optimize import differential_evolution
from sympy import *
plt.rcParams.update({'font.size': 12})
formatter = mticker.ScalarFormatter(useMathText=True)
plt.rcParams["axes.formatter.use_mathtext"] = True

# %%
def gaussiana(x, sigma, mi):
    return (1/(sigma*np.sqrt(2*np.pi)))*np.exp(-(x-mi)**2/(2*sigma**2))


def gaussiana_fit(dados_x, dados_y):
    popt, pcov = curve_fit(
    f = gaussiana,
    xdata = dados_x,
    ydata = dados_y
)
    return [popt, pcov]

# %%
c = 299792458
h = 4.135668e-15
d = 2.82e-10

# %%
gauss_kbr = pd.read_csv('./Dados/kbr_18.csv',sep='\s', decimal=',')
gauss_kbr_x_18 = np.array(gauss_kbr['Ângulo'])
gauss_kbr_x_18_e =  1e-3 * h*c/(2*d*np.sin(gauss_kbr_x_18 * np.pi/180))
gauss_kbr_y_18 = np.array(gauss_kbr['R'])

gauss_kbr = pd.read_csv('./Dados/kbr_22.csv',sep='\s', decimal=',')
gauss_kbr_x_22 = np.array(gauss_kbr['Ângulo'])
gauss_kbr_x_22_e =  1e-3 * h*c/(2*d*np.sin(gauss_kbr_x_22 * np.pi/180))
gauss_kbr_y_22 = np.array(gauss_kbr['R'])

gauss_kbr = pd.read_csv('./Dados/kbr_26.csv',sep='\s', decimal=',')
gauss_kbr_x_26 = np.array(gauss_kbr['Ângulo'])
gauss_kbr_x_26_e =  1e-3 * h*c/(2*d*np.sin(gauss_kbr_x_26 * np.pi/180))
gauss_kbr_y_26 = np.array(gauss_kbr['R'])

gauss_kbr = pd.read_csv('./Dados/kbr_30.csv',sep='\s', decimal=',')
gauss_kbr_x_30 = np.array(gauss_kbr['Ângulo'])
gauss_kbr_x_30_e =  1e-3 * h*c/(2*d*np.sin(gauss_kbr_x_30 * np.pi/180))
gauss_kbr_y_30 = np.array(gauss_kbr['R'])

gauss_kbr = pd.read_csv('./Dados/kbr_35.csv',sep='\s', decimal=',')
gauss_kbr_x_35 = np.array(gauss_kbr['Ângulo'])
gauss_kbr_x_35_e =  1e-3 * h*c/(2*d*np.sin(gauss_kbr_x_35 * np.pi/180))
gauss_kbr_y_35 = np.array(gauss_kbr['R'])
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_10600\97055365.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   gauss_kbr = pd.read_csv('./Dados/kbr_18.csv',sep='\s', decimal=',')
# C:\Users\victo\AppData\Local\Temp\ipykernel_10600\97055365.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   gauss_kbr = pd.read_csv('./Dados/kbr_22.csv',sep='\s', decimal=',')
# ...

# %% [markdown]
# Plot

# %%
# x_model = np.linspace(min(dados_x)*0.9, max(dados_x))  
# y_model = gaussiana(x_model_p, par_p[0], par_p[1])

# %%
graphWidth = 800
graphHeight = 600

f = plt.figure(figsize=(graphWidth/100.0, graphHeight/100.0), dpi=100)
grafico = f.add_subplot(111)
# plot dos pontos:
grafico3 = grafico.plot(gauss_kbr_x_35[25:34], gauss_kbr_y_35[25:34], marker = '.', markersize=5, color = 'black', linewidth = 1)
grafico3 = grafico.plot(gauss_kbr_x_35[33:43], gauss_kbr_y_35[33:43], marker = '.', markersize=5, color = 'red', linewidth = 1)


# plot do ajuste
# grafico.plot(x_model_n, y_model_n,  color = 'red')
# grafico.plot(x_model_p, y_model_p,  color = 'red')

# grafico.axvline(x = x_encontro, color = 'blue', label = f'$V_0$ = {x_encontro: .2} V', linestyle = '--')


grafico.grid(True)
grafico.set_xlabel('Eixo X') # eixo x
grafico.set_ylabel('Eixo Y') # eixo y
grafico.set_title('Título') #título
grafico.legend(loc = 'upper left', fontsize= 12)

#    plt.savefig('Acr25graus.png')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
graphWidth = 800
graphHeight = 600

f = plt.figure(figsize=(graphWidth/100.0, graphHeight/100.0), dpi=100)
grafico = f.add_subplot(111)
# plot dos pontos:
def gauss_plot(dados_x, dados_y, cor, legenda):
    grafico.plot(dados_x, dados_y, marker = '.', markersize=5, color = cor, linewidth = 1, label = '$U_a =$' + legenda + '$kV$')

gauss_plot(gauss_kbr_x_18, gauss_kbr_y_18, 'blue', '18')
gauss_plot(gauss_kbr_x_22, gauss_kbr_y_22, 'red', '22')
gauss_plot(gauss_kbr_x_26, gauss_kbr_y_26, 'green', '26')
gauss_plot(gauss_kbr_x_30, gauss_kbr_y_30, 'black', '30')
gauss_plot(gauss_kbr_x_35, gauss_kbr_y_35, 'purple', '35')
# plot do ajuste
# grafico.plot(x_model_n, y_model_n,  color = 'red')
# grafico.plot(x_model_p, y_model_p,  color = 'red')

# grafico.axvline(x = x_encontro, color = 'blue', label = f'$V_0$ = {x_encontro: .2} V', linestyle = '--')


grafico.grid(True)
grafico.set_xlabel('Ângulo (°)') # eixo x
grafico.set_ylabel('Intensidade (fótons/s)') # eixo y
grafico.set_title('Intensidade de Emissão de Raios-X\nem Função do Ângulo de Incidência') #título
grafico.legend(loc = 'upper left', fontsize= 12)

#    plt.savefig('Acr25graus.png')
plt.show()

# %%
graphWidth = 800
graphHeight = 600

f = plt.figure(figsize=(graphWidth/100.0, graphHeight/100.0), dpi=100)
grafico = f.add_subplot(111)
# plot dos pontos:
def gauss_plot(dados_x, dados_y, cor, legenda):
    grafico.plot(dados_x, dados_y, marker = '.', markersize=5, color = cor, linewidth = 1, label = '$U_a =$' + legenda + '$kV$')

gauss_plot(gauss_kbr_x_18_e, gauss_kbr_y_18, 'blue', '18')
gauss_plot(gauss_kbr_x_22_e, gauss_kbr_y_22, 'red', '22')
gauss_plot(gauss_kbr_x_26_e, gauss_kbr_y_26, 'green', '26')
gauss_plot(gauss_kbr_x_30_e, gauss_kbr_y_30, 'black', '30')
gauss_plot(gauss_kbr_x_35_e, gauss_kbr_y_35, 'purple', '35')
# plot do ajuste
# grafico.plot(x_model_n, y_model_n,  color = 'red')
# grafico.plot(x_model_p, y_model_p,  color = 'red')

# grafico.axvline(x = x_encontro, color = 'blue', label = f'$V_0$ = {x_encontro: .2} V', linestyle = '--')


grafico.grid(True)
grafico.set_xlabel('Energia (kV)') # eixo x
grafico.set_ylabel('Intensidade (fótons/s)') # eixo y
grafico.set_title('Intensidade de Emissão de Raios-X\nem Função da Energia') #título
grafico.legend(loc = 'upper right', fontsize= 12)

#    plt.savefig('Acr25graus.png')
plt.show()
