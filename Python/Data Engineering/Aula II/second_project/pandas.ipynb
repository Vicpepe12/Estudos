# %%
import pandas as pd

# %% [markdown]
# Creating DataFrame from Dictionary

# %%
data = {
    'Name': ['Victor', 'Denis', 'Cleber'],
    'Age': [20, 45, 1],
    'Score': [8.5, 3.0, 9.9]    
}

# %%
pd.DataFrame(data)
# Out:
#      Name  Age  Score
# 0  Victor   20    8.5
# 1   Denis   45    3.0
# 2  Cleber    1    9.9

# %% [markdown]
# From List of Lists:

# %%
data = [['Victor', 20, 8],
        ['Denis', 55, 3],
        ['Cleber', 2, 9]]

# %%
df = pd.DataFrame(data, columns= ['Name', 'Age', 'Score'])
df
# Out:
#      Name  Age  Score
# 0  Victor   20      8
# 1   Denis   55      3
# 2  Cleber    2      9

# %% [markdown]
# And also Files (csv, json, xlsx, etc)

# %%
file_path = './data/WorldCupMatches.csv'
df = pd.read_csv(file_path) 
df.head(2)
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
#
#                   Referee               Assistant 1            Assistant 2  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)    REGO Gilberto (BRA)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)  WARNKEN Alberto (CHI)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# ...

# %%
df.tail(2)
# Out:
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 4570   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4571   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# 4570              NaN            NaN            NaN         NaN
# 4571              NaN            NaN            NaN         NaN
#
#       Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 4570                   NaN                   NaN     NaN         NaN
# 4571                   NaN                   NaN     NaN         NaN
#
#      Assistant 2  RoundID  MatchID Home Team Initials Away Team Initials
# 4570         NaN      NaN      NaN                NaN                NaN
# 4571         NaN      NaN      NaN                NaN                NaN

# %%
df.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
df.min()
# Out:
# D:\TEMP\ipykernel_9236\3962516015.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# Year                    1930.0
# Home Team Goals            0.0
# Away Team Goals            0.0
# Attendance              2000.0
# Half-time Home Goals       0.0
# Half-time Away Goals       0.0
# RoundID                  201.0
# MatchID                   25.0
# dtype: float64

# %%
df.std()
# Out:
# D:\TEMP\ipykernel_9236\3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Year                    2.244882e+01
# Home Team Goals         1.610255e+00
# Away Team Goals         1.087573e+00
# Attendance              2.348525e+04
# Half-time Home Goals    9.374141e-01
# Half-time Away Goals    6.912519e-01
# RoundID                 2.729613e+07
# MatchID                 1.110572e+08
# Goal difference         1.437652e+00
# dtype: float64

# %%
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %%
df[['Year', 'Stadium']]
# Out:
#         Year         Stadium
# 0     1930.0         Pocitos
# 1     1930.0  Parque Central
# 2     1930.0  Parque Central
# 3     1930.0         Pocitos
# 4     1930.0  Parque Central
# ...      ...             ...
# 4567     NaN             NaN
# 4568     NaN             NaN
# 4569     NaN             NaN
# 4570     NaN             NaN
# 4571     NaN             NaN
#
# [4572 rows x 2 columns]

# %% [markdown]
# iloc selects columns and rows

# %%
df.iloc[3:10, :4]
# Out:
#      Year              Datetime    Stage             Stadium
# 3  1930.0  14 Jul 1930 - 14:50   Group 3             Pocitos
# 4  1930.0  15 Jul 1930 - 16:00   Group 1      Parque Central
# 5  1930.0  16 Jul 1930 - 14:45   Group 1      Parque Central
# 6  1930.0  17 Jul 1930 - 12:45   Group 2      Parque Central
# 7  1930.0  17 Jul 1930 - 14:45   Group 4      Parque Central
# 8  1930.0  18 Jul 1930 - 14:30   Group 3  Estadio Centenario
# 9  1930.0  19 Jul 1930 - 12:50   Group 1  Estadio Centenario

# %% [markdown]
# Boolean mask

# %%
mask = [False for _ in range(len(df))]
mask[3:8] = [True]*5
mask
# Out:
# [False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
df.loc[mask]
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930.0  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930.0  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 7  1930.0  17 Jul 1930 - 14:45   Group 4  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
# 5          Chile              3.0              0.0         Mexico
# 6     Yugoslavia              4.0              0.0        Bolivia
# 7            USA              3.0              0.0       Paraguay
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                   1.0                   0.0
# ...

# %%
mask = df.loc[:, 'Home Team Goals'] < df.loc[:, 'Away Team Goals']
mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4567    False
# 4568    False
# 4569    False
# 4570    False
# 4571    False
# Length: 4572, dtype: bool

# %%
df[mask]
# Out:
#        Year              Datetime                     Stage  \
# 103  1958.0  08 Jun 1958 - 19:00                    Group 1
# 235  1974.0  14 Jun 1974 - 19:30                    Group 2
# 236  1974.0  15 Jun 1974 - 16:00                    Group 3
# 240  1974.0  18 Jun 1974 - 16:00                    Group 1
# 246  1974.0  19 Jun 1974 - 19:30                    Group 4
# ..      ...                   ...                       ...
# 826  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 827  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 844  2014.0  04 Jul 2014 - 13:00             Quarter-finals
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
#
#                   Stadium             City Home Team Name  Home Team Goals  \
# 103         Malmo Stadion           Malm�       Argentina              1.0
# 235      Westfalenstadion        Dortmund           Zaire              0.0
# ...

# %% [markdown]
# Pandas boolean operators

# %%
df.describe()
# Out:
#               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
mask = (df.loc[:,'Away Team Goals'] > 2) & (df.loc[:, 'Half-time Away Goals'] > 1)
mask
df[mask]
# Out:
#        Year              Datetime                     Stage  \
# 94   1954.0  26 Jun 1954 - 17:00             Quarter-finals
# 103  1958.0  08 Jun 1958 - 19:00                    Group 1
# 105  1958.0  08 Jun 1958 - 19:00                    Group 2
# 121  1958.0  15 Jun 1958 - 19:00                    Group 2
# 195  1966.0  23 Jul 1966 - 15:00             Quarter-finals
# 240  1974.0  18 Jun 1974 - 16:00                    Group 1
# 246  1974.0  19 Jun 1974 - 19:30                    Group 4
# 252  1974.0  23 Jun 1974 - 16:00                    Group 3
# 390  1986.0  11 Jun 1986 - 16:00                    Group F
# 392  1986.0  12 Jun 1986 - 12:00                    Group D
# 416  1990.0  10 Jun 1990 - 17:00                    Group A
# 437  1990.0  18 Jun 1990 - 21:00                    Group B
# 468  1994.0  18 Jun 1994 - 19:30                    Group A
# 567  1998.0  28 Jun 1998 - 21:00                Round of 16
# 579  1998.0  12 Jul 1998 - 21:00                      Final
# ...

# %% [markdown]
# Creating new columns

# %%
df.loc[:, 'Goal difference'] = abs(df.loc[:, 'Home Team Goals'] - df.loc[:, 'Away Team Goals'])
df['Goal difference']
# Out:
# 0       3.0
# 1       3.0
# 2       1.0
# 3       2.0
# 4       1.0
#        ...
# 4567    NaN
# 4568    NaN
# 4569    NaN
# 4570    NaN
# 4571    NaN
# Name: Goal difference, Length: 4572, dtype: float64
